# %% [markdown]
# ### Importar librerías

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import plot_tree, export_text
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, precision_recall_curve, auc

import os

RANDOM_STATE = 0

# %%
# Importa el dataset
data = pd.read_csv(os.path.join('..', 'data', 'features_kepler_train.csv'))

# %%
# Muestra las 10 instancias aleatorias
data.sample(10)
# Out:
#      mission    koi_id   koi_name  koi_time0bk  koi_period  koi_duration  \
# 2859  Kepler   7119481  K00566.01   192.574840   25.855000      0.161404
# 3561  Kepler   8483241  K04270.01   178.182500  373.722570      0.592083
# 1568  Kepler   8495415  K02362.02   355.036270   11.085077      0.072958
# 5279  Kepler   6033602  K05225.01   141.530200   33.294801      0.124875
# 3369  Kepler   5024177  K04286.01   131.739390    0.787120      0.131867
# 5931  Kepler   9048145  K06063.01   137.341530    8.667826      0.211048
# 736   Kepler   8552583  K01265.01   133.848010    1.061935      0.135629
# 2633  Kepler  10189546  K00427.03   245.651510  117.033521      0.284250
# 4960  Kepler   4544572  K03950.01   132.082757    2.189093      0.213033
# 5337  Kepler   5179609  K05132.01   134.214029   43.931160      0.539146
#
#       koi_is_planet
# 2859              1
# 3561              0
# 1568              1
# 5279              0
# 3369              0
# 5931              0
# 736               0
# 2633              1
# 4960              0
# 5337              0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7507 entries, 0 to 7506
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   mission        7507 non-null   object
#  1   koi_id         7507 non-null   int64
#  2   koi_name       7507 non-null   object
#  3   koi_time0bk    7507 non-null   float64
#  4   koi_period     7507 non-null   float64
#  5   koi_duration   7507 non-null   float64
#  6   koi_is_planet  7507 non-null   int64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 410.7+ KB

# %%
# En valores absolutos
data['koi_is_planet'].value_counts()
# Out:
# 0    4839
# 1    2668
# Name: koi_is_planet, dtype: int64

# %%
# En proporción
data['koi_is_planet'].value_counts(normalize=True)
# Out:
# 0    0.644598
# 1    0.355402
# Name: koi_is_planet, dtype: float64

# %%
data.describe()
# Out:
#              koi_id  koi_time0bk   koi_period  koi_duration  koi_is_planet
# count  7.507000e+03  7507.000000  7507.000000   7507.000000    7507.000000
# mean   7.634346e+06   162.343089    51.798869      0.238579       0.355402
# std    2.637355e+06    62.866438   112.155710      0.285361       0.478667
# min    7.574500e+05   120.515914     0.241843      0.004358       0.000000
# 25%    5.513845e+06   132.551270     2.224613      0.103333       0.000000
# 50%    7.819520e+06   136.379520     8.041348      0.160117       0.000000
# 75%    9.837582e+06   169.904485    30.582145      0.261625       1.000000
# max    1.293514e+07  1472.522306  1071.232624      5.772500       1.000000

# %%
# Haz el reemplazo
columns_to_replace = ['koi_id', 'koi_time0bk', 'koi_period', 'koi_duration']
data[columns_to_replace] = data[columns_to_replace].replace(0, np.NaN)

# %%
# Recuento de nulos
data.isnull().sum()
# Out:
# mission          0
# koi_id           0
# koi_name         0
# koi_time0bk      0
# koi_period       0
# koi_duration     0
# koi_is_planet    0
# dtype: int64

# %%
# Imputa los valores
data = data.fillna(data.median())
# Out:
# C:\Users\bisqu\AppData\Local\Temp/ipykernel_9924/2486533195.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data = data.fillna(data.median())

# %%
# Recuento de nulos
data.isnull().sum()
# Out:
# mission          0
# koi_id           0
# koi_name         0
# koi_time0bk      0
# koi_period       0
# koi_duration     0
# koi_is_planet    0
# dtype: int64

# %%
# Muestra un nuevo resumen estadístico para comprobar que está todo ok
data.describe()
# Out:
#              koi_id  koi_time0bk   koi_period  koi_duration  koi_is_planet
# count  7.507000e+03  7507.000000  7507.000000   7507.000000    7507.000000
# mean   7.634346e+06   162.343089    51.798869      0.238579       0.355402
# std    2.637355e+06    62.866438   112.155710      0.285361       0.478667
# min    7.574500e+05   120.515914     0.241843      0.004358       0.000000
# 25%    5.513845e+06   132.551270     2.224613      0.103333       0.000000
# 50%    7.819520e+06   136.379520     8.041348      0.160117       0.000000
# 75%    9.837582e+06   169.904485    30.582145      0.261625       1.000000
# max    1.293514e+07  1472.522306  1071.232624      5.772500       1.000000

# %%
for column in data.columns[:-1]:
    plt.figure(figsize=(8, 6))
    sns.boxplot(x='koi_is_planet', y=column, data=data)
    plt.xlabel('koi_is_planet')
    plt.title(f"Distribución de la variable '{column}'");

# %%
sns.pairplot(data, hue='koi_is_planet', palette='magma');

# %%
data = pd.get_dummies(data, drop_first=True)
data

# %%
fig, ax = plt.subplots(figsize=(20, 20))
sns.heatmap(data.corr(), annot=True, fmt='.2f');

# %%
X = data.drop(['koi_time0bk', 'koi_period', 'koi_duration'], axis=1)
y = data['koi_is_planet']

# %% [markdown]
# **Divide el dataset en los conjuntos de entrenamiento y prueba en una proporción de 75/25. Usa `RANDOM_STATE` y estratifica la división en función de la variable de salida.**

# %%
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    stratify=y,
                                                    random_state=RANDOM_STATE)

# %% [markdown]
# **Normaliza los datos de entrenamiento y prueba usando la función `StandardScaler()` de la librería Scikit-Learn.**

# %%
# Escala el conjunto de entrenamiento
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)

# %%
# Recrea el dataset de entrenamiento con las columnas estandarizadas
X_train = pd.DataFrame(X_train_scaled, columns=X.columns)
X_train.head()
# Out:
#    Pregnancies   Glucose  SkinThickness       BMI  DiabetesPedigreeFunction  \
# 0    -0.877817 -1.390108      -2.072727 -0.343280                  0.160307
# 1    -0.584872 -0.092805      -0.054694 -1.882723                  1.057927
# 2     1.758685 -0.225861      -0.054694 -0.002827                 -0.622535
# 3    -0.877817  1.969575       1.402774  1.136953                  2.311652
# 4     0.001017 -0.824617      -0.727372 -0.609722                 -0.086906
#
#         Age  pregnancies_age   bmi_age  skin_age  glucose_age  insulin_age  \
# 0 -0.980244        -0.800612  0.811559 -1.182496    -0.223734    -0.595278
# 1  3.203371        -1.014562 -2.106208 -1.433630    -1.697979    -0.927249
# 2 -0.310866         2.683707  0.044380  0.022945    -0.077342    -0.113179
# 3 -0.980244        -0.800612  2.026733  2.457309     3.188332     2.951952
# 4 -0.980244         0.849855  0.592828  0.226461     0.350574     0.394293
#
#    insulin_glucose  BMI_cat_Obesity  BMI_cat_Overweight  BMI_cat_Underweight  \
# 0        -0.860104         0.786115           -0.569331            -0.059028
# 1        -0.205381        -1.272078           -0.569331            -0.059028
# 2        -0.237873         0.786115           -0.569331            -0.059028
# 3         2.274316         0.786115           -0.569331            -0.059028
# 4        -0.384089        -1.272078            1.756447            -0.059028
#
#    Glucose_cat_Prediabetes  BP_cat_Normal  BP_cat_Stage 1 HT  \
# 0                -0.574677       0.614809          -0.485851
# 1                -0.574677       0.614809          -0.485851
# 2                -0.574677       0.614809          -0.485851
# 3                 1.740107       0.614809          -0.485851
# 4                -0.574677       0.614809          -0.485851
#
#    BP_cat_Stage 2 HT  Insulin_cat_Normal
# 0          -0.298072             0.48312
# 1          -0.298072             0.48312
# 2          -0.298072             0.48312
# 3          -0.298072            -2.06988
# 4          -0.298072             0.48312

# %%
# Escala el conjunto de prueba
X_test_scaled = scaler.transform(X_test)

# %%
# Recrea el dataset de prueba con las columnas estandarizadas
X_test = pd.DataFrame(X_test_scaled, columns=X.columns)
X_test.head()
# Out:
#    Pregnancies   Glucose  SkinThickness       BMI  DiabetesPedigreeFunction  \
# 0    -0.584872 -0.525239       0.617984 -0.269269                  2.729560
# 1    -0.584872 -0.891145      -1.736388 -0.920571                  0.810714
# 2    -0.877817 -0.724824      -0.054694 -0.047234                 -0.083963
# 3    -1.170761  0.140045      -0.278920 -0.728141                  0.124991
# 4     0.586906 -0.625032      -0.054694 -1.187013                 -0.657851
#
#         Age  pregnancies_age   bmi_age  skin_age  glucose_age  insulin_age  \
# 0  0.023823        -0.638802 -0.435781  0.185021    -0.609256    -0.336467
# 1 -0.980244        -0.250457  0.337642 -0.830257     0.283009    -0.169001
# 2  0.693202        -1.062591 -0.797099 -0.690480    -1.156784     0.054287
# 3 -1.063917        -1.350768  0.654165  0.847073     1.532973     0.405167
# 4 -0.394538         1.153389 -0.593852  0.109048    -0.286640    -0.065057
#
#    insulin_glucose  BMI_cat_Obesity  BMI_cat_Overweight  BMI_cat_Underweight  \
# 0        -0.352312         0.786115           -0.569331            -0.059028
# 1        -0.628758        -1.272078            1.756447            -0.059028
# 2         0.101673         0.786115           -0.569331            -0.059028
# 3        -0.189459        -1.272078            1.756447            -0.059028
# 4        -0.335351        -1.272078           -0.569331            -0.059028
#
#    Glucose_cat_Prediabetes  BP_cat_Normal  BP_cat_Stage 1 HT  \
# 0                -0.574677       0.614809          -0.485851
# 1                -0.574677       0.614809          -0.485851
# 2                -0.574677       0.614809          -0.485851
# 3                -0.574677      -1.626521           2.058243
# 4                -0.574677       0.614809          -0.485851
#
#    BP_cat_Stage 2 HT  Insulin_cat_Normal
# 0          -0.298072             0.48312
# 1          -0.298072             0.48312
# 2          -0.298072            -2.06988
# 3          -0.298072             0.48312
# 4          -0.298072             0.48312

# %% [markdown]
# **RANDOM_STATE**

# %%
# Te proponemos usar los siguientes parámetros, pero usa los que consideres
lr_params = {'C': [1, 10, 100],
             'max_iter': [200, 500, 1000]}

# %%
# Optimiza el clasificador
lr_gs = GridSearchCV(LogisticRegression(random_state=RANDOM_STATE), 
                     lr_params,
                     cv=3).fit(X_train, y_train)

# %%
# Muestra los mejores parámetros
lr_gs.best_params_
# Out:
# {'C': 10, 'max_iter': 200}

# %%
# Entrena el clasificador con los parámetros óptimos
lr_tuned = LogisticRegression(**lr_gs.best_params_, random_state=RANDOM_STATE)
lr_tuned.fit(X_train, y_train)
# Out:
# LogisticRegression(C=10, max_iter=200, random_state=0)

# %%
print(f'Test accuracy - {round(lr_tuned.score(X_test, y_test) * 100, 2)}%')
# Out:
# Test accuracy - 77.08%

# %%
y_pred = lr_tuned.predict(X_test)

# %%
# Calcula la matriz de confusión
conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=[8, 6])
sns.heatmap(conf_matrix,
            annot=True,
            fmt='d')
plt.title('Confusion matrix')
plt.ylabel('True class')
plt.xlabel('Predicted class');

# %%
# Imprime el informe de clasificación
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.87      0.83       125
#            1       0.71      0.58      0.64        67
#
#     accuracy                           0.77       192
#    macro avg       0.75      0.73      0.74       192
# weighted avg       0.77      0.77      0.76       192

# %% [markdown]
# **RANDOM FOREST**

# %%
# Te proponemos usar los siguientes parámetros, pero usa los que consideres
rf_params = {'n_estimators' :[100, 200, 500, 1000],
             'max_depth': [3, 5, 8, 10]}

# %%
# Optimiza el clasificador
rf_gs = GridSearchCV(RandomForestClassifier(random_state=RANDOM_STATE), 
                     rf_params,
                     cv=3).fit(X_train, y_train)

# %%
# Muestra los mejores parámetros
rf_gs.best_params_
# Out:
# {'max_depth': 8, 'n_estimators': 200}

# %%
# Entrena el clasificador con los parámetros óptimos
rf_tuned = RandomForestClassifier(**rf_gs.best_params_, random_state=RANDOM_STATE)
rf_tuned.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=8, n_estimators=200, random_state=0)

# %%
print(f'Test accuracy - {round(rf_tuned.score(X_test, y_test) * 100, 2)}%')
# Out:
# Test accuracy - 78.65%

# %%
y_pred = rf_tuned.predict(X_test)

# %%
# Calcula la matriz de confusión
conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=[8, 6])
sns.heatmap(conf_matrix,
            annot=True,
            fmt='d')
plt.title('Confusion matrix')
plt.ylabel('True class')
plt.xlabel('Predicted class');

# %%
# Imprime el informe de clasificación
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.86      0.84       125
#            1       0.72      0.64      0.68        67
#
#     accuracy                           0.79       192
#    macro avg       0.77      0.75      0.76       192
# weighted avg       0.78      0.79      0.78       192

# %%
# Muestra la importancia de las características
feat_importances = pd.DataFrame(rf_tuned.feature_importances_,
                                index=X.columns,
                                columns=['Importance'])
feat_importances.sort_values(by='Importance', ascending=True, inplace=True)

ax = feat_importances[feat_importances['Importance'] > 0].plot(kind='barh',
                                                               figsize=(8, 6),
                                                               color='yellowgreen')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.get_legend().remove()

for p in ax.patches:
    width = p.get_width()
    plt.text(width,
             p.get_y() + 0.5 * p.get_height(),
             '{:1.2f}%'.format(width * 100),
             ha='left',
             va='center')

# %%
estimator = 10
plt.figure(figsize=(20, rf_tuned.estimators_[estimator].get_depth() * 1))
plot_tree(rf_tuned.estimators_[estimator],
               feature_names=X.columns,
               class_names=['0', '1'],
               filled=True)

plt.title('Estimator ' + str(estimator), fontsize=12)

plt.savefig(f'rf_individualtree_{estimator}.png', dpi=300)

# %%
# Crea un informe de texto que muestra las reglas del árbol de decisión
print(export_text(rf_tuned.estimators_[estimator], feature_names=list(X.columns)))
# Out:
# |--- BMI <= -0.88
# |   |--- Glucose_cat_Prediabetes <= 0.58
# |   |   |--- insulin_age <= -0.80
# |   |   |   |--- bmi_age <= -1.88
# |   |   |   |   |--- class: 0.0
# |   |   |   |--- bmi_age >  -1.88
# |   |   |   |   |--- Glucose <= -0.59
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- Glucose >  -0.59
# |   |   |   |   |   |--- class: 1.0
# |   |   |--- insulin_age >  -0.80
# |   |   |   |--- class: 0.0
# |   |--- Glucose_cat_Prediabetes >  0.58
# |   |   |--- Glucose <= 1.05
# |   |   |   |--- class: 0.0
# |   |   |--- Glucose >  1.05
# |   |   |   |--- pregnancies_age <= -0.51
# |   |   |   |   |--- class: 0.0
# |   |   |   |--- pregnancies_age >  -0.51
# |   |   |   |   |--- class: 1.0
# |--- BMI >  -0.88
# |   |--- insulin_glucose <= -0.27
# |   |   |--- Age <= -0.69
# |   |   |   |--- class: 0.0
# |   |   |--- Age >  -0.69
# |   |   |   |--- bmi_age <= -1.44
# |   |   |   |   |--- class: 1.0
# |   |   |   |--- bmi_age >  -1.44
# |   |   |   |   |--- glucose_age <= -1.04
# |   |   |   |   |   |--- bmi_age <= -1.10
# |   |   |   |   |   |   |--- Pregnancies <= 1.47
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- Pregnancies >  1.47
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- bmi_age >  -1.10
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- glucose_age >  -1.04
# |   |   |   |   |   |--- Age <= -0.19
# |   |   |   |   |   |   |--- DiabetesPedigreeFunction <= 1.93
# |   |   |   |   |   |   |   |--- Age <= -0.44
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- Age >  -0.44
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- DiabetesPedigreeFunction >  1.93
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- Age >  -0.19
# |   |   |   |   |   |   |--- Pregnancies <= 0.73
# |   |   |   |   |   |   |   |--- glucose_age <= -0.37
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- glucose_age >  -0.37
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- Pregnancies >  0.73
# |   |   |   |   |   |   |   |--- pregnancies_age <= 1.33
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- pregnancies_age >  1.33
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |--- insulin_glucose >  -0.27
# |   |   |--- Age <= -0.27
# |   |   |   |--- insulin_glucose <= 3.69
# |   |   |   |   |--- Glucose <= 1.25
# |   |   |   |   |   |--- BMI <= -0.71
# |   |   |   |   |   |   |--- Pregnancies <= -0.73
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- Pregnancies >  -0.73
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- BMI >  -0.71
# |   |   |   |   |   |   |--- insulin_age <= 1.27
# |   |   |   |   |   |   |   |--- skin_age <= 0.74
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- skin_age >  0.74
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- insulin_age >  1.27
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- Glucose >  1.25
# |   |   |   |   |   |--- DiabetesPedigreeFunction <= -0.05
# |   |   |   |   |   |   |--- pregnancies_age <= -0.59
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- pregnancies_age >  -0.59
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- DiabetesPedigreeFunction >  -0.05
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- insulin_glucose >  3.69
# |   |   |   |   |--- class: 1.0
# |   |   |--- Age >  -0.27
# |   |   |   |--- Glucose_cat_Prediabetes <= 0.58
# |   |   |   |   |--- bmi_age <= -1.40
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- bmi_age >  -1.40
# |   |   |   |   |   |--- SkinThickness <= -1.46
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- SkinThickness >  -1.46
# |   |   |   |   |   |   |--- BMI <= 1.32
# |   |   |   |   |   |   |   |--- Pregnancies <= -0.58
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- Pregnancies >  -0.58
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- BMI >  1.32
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- Glucose_cat_Prediabetes >  0.58
# |   |   |   |   |--- Glucose <= 2.49
# |   |   |   |   |   |--- SkinThickness <= -1.29
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- SkinThickness >  -1.29
# |   |   |   |   |   |   |--- Age <= 0.69
# |   |   |   |   |   |   |   |--- insulin_age <= -0.29
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- insulin_age >  -0.29
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- Age >  0.69
# |   |   |   |   |   |   |   |--- Glucose <= 1.39
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- Glucose >  1.39
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- Glucose >  2.49
# |   |   |   |   |   |--- class: 0.0

# %%
# Calcula las probabilidades de predicción
y_proba_rf = rf_tuned.predict_proba(X_test)

# %%
# Probamos usando las probabilidades del clasificador random forest
precision, recall, thresholds = precision_recall_curve(y_test, y_proba_rf[:, 1])
pr_auc = auc(recall, precision)

# Calculamos el codo de la curva
closest_zero = np.argmin(np.abs(thresholds))
closest_zero_p = precision[closest_zero]
closest_zero_r = recall[closest_zero]

# Establecemos el tamaño de los ejes
plt.xlim([0.0, 1.01])
plt.ylim([0.0, 1.01])

# Dibujamos la línea del clasificador aleatorio
no_skill = len(y_test[y_test == 1]) / len(y_test)
plt.plot([0, 1], [no_skill, no_skill], linestyle='--', label='No Skill', c='r')
# Dibujamos la curva de precisión-sensibilidad del clasificador
plt.plot(precision, recall, label='Random Forest', c='b')

plt.title(f'Precision-Recall Curve (AUC={pr_auc:.2f})')
plt.xlabel('Precision')
plt.ylabel('Recall')
plt.legend();
